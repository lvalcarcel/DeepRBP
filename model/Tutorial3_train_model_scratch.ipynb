# %% [markdown]
# # Tutorial 3: How to train the DeepRBP predictor from scratch.

# %%
import argparse
import pandas as pd
import os
import json
import torch
import sys
import uuid
import joblib
import numpy as np

from utils.Utils import get_data, scale_rbp_input_data, create_data_loader, build_optimizer
#from utils.Plots import *
from utils.Config import Config
from DLModelClass.modelsNN import DeepRBP

# %% [markdown]
# ## 1. Setting Up Model Configuration and Saving Results
#
# First, we are going to create the Config object where we define various parameters that will be used to configure the model. These
# parameters include the maximum number of nodes in the hidden layers (`max_node`), the number of hidden layers (`num_hidden_layers`),
# the learning rate (`learning_rate`), batch size (`batch_size`), the number of epochs (`epochs`), among others.
#
# A unique identifier unique_id is generated using uuid.uuid4().hex[:8], and a 'path_save_files' path is
# created to save the results in a specific folder within the output directory (`./output/`). If the folder doesn't exist, it is created.
#
# After that we save the created model configuration to a JSON File in the results folder.

# %%
config = Config(
             max_node = 1024,
             num_hidden_layers = 2,
             learning_rate = 0.001,
             batch_size = 128,
             epochs = 100,
             same_num_nodes = False, 
             node_divition_factor = 4,
             activation_layer = 'relu',
             optimizer = 'adamW',
             source_train = 'TCGA',
             train_tumor_types = 'all')
print(config.get_config())

# Create the results folder
unique_id = uuid.uuid4().hex[:8]
path_save_files = f'./output/{unique_id}'

if not os.path.exists(path_save_files):
    os.makedirs(path_save_files)
    
# We are going to create the .json for the model we're gonna train with the actual settings
with open(path_save_files+'/config.json', 'w') as file:
   json.dump(config.get_config(), file)
# Out:
# {'max_node': 1024, 'num_hidden_layers': 2, 'learning_rate': 0.001, 'batch_size': 128, 'epochs': 100, 'same_num_nodes': False, 'node_divition_factor': 4, 'activation_layer': 'relu', 'optimizer': 'adamW', 'source_train': 'TCGA', 'train_tumor_types': 'all', 'test_tumor_types': 'all'}

# %% [markdown]
# ## 2. Get and process the data
#
# In this tutorial, we will use the TCGA dataset to train the model saved in `path_data`. If you haven't downloaded and processed this data yet, please run the following two shell scripts:
#
# ```bash
# sh data/input_create_model/raw/download_script.sh
# sh data/input_create_model/processed/create_data.sh
# ```

# %%
path_data = '../data/input_create_model/processed'

# %% [markdown]
# ### 2.1. Get the data
# In this step, we'll gather the training raw data for RBP, gene, and transcript expression, utilizing the tumor type samples specified in `config.train_tumor_types` from the study defined in `source_train`.
#
# To conserve computational resources, we set `toy_set` to true, indicating that this is a toy example using a 15% fraction of all TCGA samples, specified by the variable `frac`.
#
# The data will be divided into training and validation sets, and the combined data will be returned in the `data_raw` variable.

# %%
data_raw = get_data(config=config, path=path_data, toy_set=True, frac=0.15)
# Out:
# [Utils][get_data] set_mode is training
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Lung_Squamous_Cell_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Lung_Squamous_Cell_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Lung_Squamous_Cell_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (52, 1284)
# [Utils][get_data] df_validation.shape: (14, 1284)
# [Utils][get_data] train_labels.shape: (52, 11459)
# [Utils][get_data] valid_labels.shape: (14, 11459)
# [Utils][get_data] train_gn.shape: (52, 11459)
# [Utils][get_data] valid_gn.shape: (14, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Cholangiocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Cholangiocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Cholangiocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (4, 1284)
# [Utils][get_data] df_validation.shape: (1, 1284)
# [Utils][get_data] train_labels.shape: (4, 11459)
# [Utils][get_data] valid_labels.shape: (1, 11459)
# [Utils][get_data] train_gn.shape: (4, 11459)
# [Utils][get_data] valid_gn.shape: (1, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Stomach_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Stomach_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Stomach_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (43, 1284)
# [Utils][get_data] df_validation.shape: (11, 1284)
# [Utils][get_data] train_labels.shape: (43, 11459)
# [Utils][get_data] valid_labels.shape: (11, 11459)
# [Utils][get_data] train_gn.shape: (43, 11459)
# [Utils][get_data] valid_gn.shape: (11, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Ovarian_Serous_Cystadenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Ovarian_Serous_Cystadenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Ovarian_Serous_Cystadenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (40, 1284)
# [Utils][get_data] df_validation.shape: (11, 1284)
# [Utils][get_data] train_labels.shape: (40, 11459)
# [Utils][get_data] valid_labels.shape: (11, 11459)
# [Utils][get_data] train_gn.shape: (40, 11459)
# [Utils][get_data] valid_gn.shape: (11, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Liver_Hepatocellular_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Liver_Hepatocellular_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Liver_Hepatocellular_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (40, 1284)
# [Utils][get_data] df_validation.shape: (10, 1284)
# [Utils][get_data] train_labels.shape: (40, 11459)
# [Utils][get_data] valid_labels.shape: (10, 11459)
# [Utils][get_data] train_gn.shape: (40, 11459)
# [Utils][get_data] valid_gn.shape: (10, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Kidney_Chromophobe
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Kidney_Chromophobe tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Kidney_Chromophobe in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (8, 1284)
# [Utils][get_data] df_validation.shape: (3, 1284)
# [Utils][get_data] train_labels.shape: (8, 11459)
# [Utils][get_data] valid_labels.shape: (3, 11459)
# [Utils][get_data] train_gn.shape: (8, 11459)
# [Utils][get_data] valid_gn.shape: (3, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Uterine_Carcinosarcoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Uterine_Carcinosarcoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Uterine_Carcinosarcoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (5, 1284)
# [Utils][get_data] df_validation.shape: (2, 1284)
# [Utils][get_data] train_labels.shape: (5, 11459)
# [Utils][get_data] valid_labels.shape: (2, 11459)
# [Utils][get_data] train_gn.shape: (5, 11459)
# [Utils][get_data] valid_gn.shape: (2, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Bladder_Urothelial_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Bladder_Urothelial_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Bladder_Urothelial_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (40, 1284)
# [Utils][get_data] df_validation.shape: (10, 1284)
# [Utils][get_data] train_labels.shape: (40, 11459)
# [Utils][get_data] valid_labels.shape: (10, 11459)
# [Utils][get_data] train_gn.shape: (40, 11459)
# [Utils][get_data] valid_gn.shape: (10, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Glioblastoma_Multiforme
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Glioblastoma_Multiforme tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Glioblastoma_Multiforme in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (16, 1284)
# [Utils][get_data] df_validation.shape: (4, 1284)
# [Utils][get_data] train_labels.shape: (16, 11459)
# [Utils][get_data] valid_labels.shape: (4, 11459)
# [Utils][get_data] train_gn.shape: (16, 11459)
# [Utils][get_data] valid_gn.shape: (4, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Uterine_Corpus_Endometrioid_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Uterine_Corpus_Endometrioid_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Uterine_Corpus_Endometrioid_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (19, 1284)
# [Utils][get_data] df_validation.shape: (5, 1284)
# [Utils][get_data] train_labels.shape: (19, 11459)
# [Utils][get_data] valid_labels.shape: (5, 11459)
# [Utils][get_data] train_gn.shape: (19, 11459)
# [Utils][get_data] valid_gn.shape: (5, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Testicular_Germ_Cell_Tumor
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Testicular_Germ_Cell_Tumor tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Testicular_Germ_Cell_Tumor in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (14, 1284)
# [Utils][get_data] df_validation.shape: (4, 1284)
# [Utils][get_data] train_labels.shape: (14, 11459)
# [Utils][get_data] valid_labels.shape: (4, 11459)
# [Utils][get_data] train_gn.shape: (14, 11459)
# [Utils][get_data] valid_gn.shape: (4, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Kidney_Papillary_Cell_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Kidney_Papillary_Cell_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Kidney_Papillary_Cell_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (30, 1284)
# [Utils][get_data] df_validation.shape: (8, 1284)
# [Utils][get_data] train_labels.shape: (30, 11459)
# [Utils][get_data] valid_labels.shape: (8, 11459)
# [Utils][get_data] train_gn.shape: (30, 11459)
# [Utils][get_data] valid_gn.shape: (8, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Prostate_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Prostate_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Prostate_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (52, 1284)
# [Utils][get_data] df_validation.shape: (14, 1284)
# [Utils][get_data] train_labels.shape: (52, 11459)
# [Utils][get_data] valid_labels.shape: (14, 11459)
# [Utils][get_data] train_gn.shape: (52, 11459)
# [Utils][get_data] valid_gn.shape: (14, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Acute_Myeloid_Leukemia
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Acute_Myeloid_Leukemia tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Acute_Myeloid_Leukemia in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (16, 1284)
# [Utils][get_data] df_validation.shape: (5, 1284)
# [Utils][get_data] train_labels.shape: (16, 11459)
# [Utils][get_data] valid_labels.shape: (5, 11459)
# [Utils][get_data] train_gn.shape: (16, 11459)
# [Utils][get_data] valid_gn.shape: (5, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Breast_Invasive_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Breast_Invasive_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Breast_Invasive_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (116, 1284)
# [Utils][get_data] df_validation.shape: (29, 1284)
# [Utils][get_data] train_labels.shape: (116, 11459)
# [Utils][get_data] valid_labels.shape: (29, 11459)
# [Utils][get_data] train_gn.shape: (116, 11459)
# [Utils][get_data] valid_gn.shape: (29, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Pancreatic_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Pancreatic_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Pancreatic_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (17, 1284)
# [Utils][get_data] df_validation.shape: (5, 1284)
# [Utils][get_data] train_labels.shape: (17, 11459)
# [Utils][get_data] valid_labels.shape: (5, 11459)
# [Utils][get_data] train_gn.shape: (17, 11459)
# [Utils][get_data] valid_gn.shape: (5, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Pheochromocytoma_&_Paraganglioma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Pheochromocytoma_&_Paraganglioma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Pheochromocytoma_&_Paraganglioma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (17, 1284)
# [Utils][get_data] df_validation.shape: (5, 1284)
# [Utils][get_data] train_labels.shape: (17, 11459)
# [Utils][get_data] valid_labels.shape: (5, 11459)
# [Utils][get_data] train_gn.shape: (17, 11459)
# [Utils][get_data] valid_gn.shape: (5, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Rectum_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Rectum_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Rectum_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (9, 1284)
# [Utils][get_data] df_validation.shape: (3, 1284)
# [Utils][get_data] train_labels.shape: (9, 11459)
# [Utils][get_data] valid_labels.shape: (3, 11459)
# [Utils][get_data] train_gn.shape: (9, 11459)
# [Utils][get_data] valid_gn.shape: (3, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Lung_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Lung_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Lung_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (55, 1284)
# [Utils][get_data] df_validation.shape: (14, 1284)
# [Utils][get_data] train_labels.shape: (55, 11459)
# [Utils][get_data] valid_labels.shape: (14, 11459)
# [Utils][get_data] train_gn.shape: (55, 11459)
# [Utils][get_data] valid_gn.shape: (14, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Sarcoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Sarcoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Sarcoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (25, 1284)
# [Utils][get_data] df_validation.shape: (7, 1284)
# [Utils][get_data] train_labels.shape: (25, 11459)
# [Utils][get_data] valid_labels.shape: (7, 11459)
# [Utils][get_data] train_gn.shape: (25, 11459)
# [Utils][get_data] valid_gn.shape: (7, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Uveal_Melanoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Uveal_Melanoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Uveal_Melanoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (7, 1284)
# [Utils][get_data] df_validation.shape: (2, 1284)
# [Utils][get_data] train_labels.shape: (7, 11459)
# [Utils][get_data] valid_labels.shape: (2, 11459)
# [Utils][get_data] train_gn.shape: (7, 11459)
# [Utils][get_data] valid_gn.shape: (2, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Skin_Cutaneous_Melanoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Skin_Cutaneous_Melanoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Skin_Cutaneous_Melanoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (44, 1284)
# [Utils][get_data] df_validation.shape: (12, 1284)
# [Utils][get_data] train_labels.shape: (44, 11459)
# [Utils][get_data] valid_labels.shape: (12, 11459)
# [Utils][get_data] train_gn.shape: (44, 11459)
# [Utils][get_data] valid_gn.shape: (12, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Colon_Adenocarcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Colon_Adenocarcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Colon_Adenocarcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (32, 1284)
# [Utils][get_data] df_validation.shape: (8, 1284)
# [Utils][get_data] train_labels.shape: (32, 11459)
# [Utils][get_data] valid_labels.shape: (8, 11459)
# [Utils][get_data] train_gn.shape: (32, 11459)
# [Utils][get_data] valid_gn.shape: (8, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Cervical_&_Endocervical_Cancer
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Cervical_&_Endocervical_Cancer tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Cervical_&_Endocervical_Cancer in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (29, 1284)
# [Utils][get_data] df_validation.shape: (8, 1284)
# [Utils][get_data] train_labels.shape: (29, 11459)
# [Utils][get_data] valid_labels.shape: (8, 11459)
# [Utils][get_data] train_gn.shape: (29, 11459)
# [Utils][get_data] valid_gn.shape: (8, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Esophageal_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Esophageal_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Esophageal_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (18, 1284)
# [Utils][get_data] df_validation.shape: (5, 1284)
# [Utils][get_data] train_labels.shape: (18, 11459)
# [Utils][get_data] valid_labels.shape: (5, 11459)
# [Utils][get_data] train_gn.shape: (18, 11459)
# [Utils][get_data] valid_gn.shape: (5, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Head_&_Neck_Squamous_Cell_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Head_&_Neck_Squamous_Cell_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Head_&_Neck_Squamous_Cell_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (54, 1284)
# [Utils][get_data] df_validation.shape: (14, 1284)
# [Utils][get_data] train_labels.shape: (54, 11459)
# [Utils][get_data] valid_labels.shape: (14, 11459)
# [Utils][get_data] train_gn.shape: (54, 11459)
# [Utils][get_data] valid_gn.shape: (14, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Thyroid_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Thyroid_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Thyroid_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (54, 1284)
# [Utils][get_data] df_validation.shape: (14, 1284)
# [Utils][get_data] train_labels.shape: (54, 11459)
# [Utils][get_data] valid_labels.shape: (14, 11459)
# [Utils][get_data] train_gn.shape: (54, 11459)
# [Utils][get_data] valid_gn.shape: (14, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Adrenocortical_Cancer
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Adrenocortical_Cancer tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Adrenocortical_Cancer in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (7, 1284)
# [Utils][get_data] df_validation.shape: (2, 1284)
# [Utils][get_data] train_labels.shape: (7, 11459)
# [Utils][get_data] valid_labels.shape: (2, 11459)
# [Utils][get_data] train_gn.shape: (7, 11459)
# [Utils][get_data] valid_gn.shape: (2, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Kidney_Clear_Cell_Carcinoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Kidney_Clear_Cell_Carcinoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Kidney_Clear_Cell_Carcinoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (57, 1284)
# [Utils][get_data] df_validation.shape: (15, 1284)
# [Utils][get_data] train_labels.shape: (57, 11459)
# [Utils][get_data] valid_labels.shape: (15, 11459)
# [Utils][get_data] train_gn.shape: (57, 11459)
# [Utils][get_data] valid_gn.shape: (15, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Diffuse_Large_B_Cell_Lymphoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Diffuse_Large_B_Cell_Lymphoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Diffuse_Large_B_Cell_Lymphoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (4, 1284)
# [Utils][get_data] df_validation.shape: (2, 1284)
# [Utils][get_data] train_labels.shape: (4, 11459)
# [Utils][get_data] valid_labels.shape: (2, 11459)
# [Utils][get_data] train_gn.shape: (4, 11459)
# [Utils][get_data] valid_gn.shape: (2, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Thymoma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Thymoma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Thymoma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (11, 1284)
# [Utils][get_data] df_validation.shape: (3, 1284)
# [Utils][get_data] train_labels.shape: (11, 11459)
# [Utils][get_data] valid_labels.shape: (3, 11459)
# [Utils][get_data] train_gn.shape: (11, 11459)
# [Utils][get_data] valid_gn.shape: (3, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Brain_Lower_Grade_Glioma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Brain_Lower_Grade_Glioma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Brain_Lower_Grade_Glioma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (50, 1284)
# [Utils][get_data] df_validation.shape: (13, 1284)
# [Utils][get_data] train_labels.shape: (50, 11459)
# [Utils][get_data] valid_labels.shape: (13, 11459)
# [Utils][get_data] train_gn.shape: (50, 11459)
# [Utils][get_data] valid_gn.shape: (13, 11459)
# [Utils][get_data] path_raw:  ../data/input_create_model/processed/splitted_datasets/TCGA/training/Mesothelioma
# [Utils][get_data] tumor_type & source columns added to this set ... -> DONE
# [Utils][get_data] You are taking 15% of the samples for Mesothelioma tumor type
# [Utils][get_data] You are performing a train-test split
# [Utils][get_data] Divide data in Mesothelioma in Training/Validation ... -> DONE
# [Utils][get_data] df_train.shape: (8, 1284)
# [Utils][get_data] df_validation.shape: (2, 1284)
# [Utils][get_data] train_labels.shape: (8, 11459)
# [Utils][get_data] valid_labels.shape: (2, 11459)
# [Utils][get_data] train_gn.shape: (8, 11459)
# [Utils][get_data] valid_gn.shape: (2, 11459)

# %% [markdown]
# Let's take a closer look at the data stored in the `data_raw` variable:
#
# * `df_train`
#  and `df_val`: these contain the training and validation sets with RBP expression in *log2(TPM+1)*, with dimensions *num_samples x n_rbps*.
# * `train_labels` and `valid_labels`: these hold the training and validation sets with transcript expression in *log2(TPM+1)*, with dimensions *num_samples x n_transcripts*.
# * `train_gn` and `valid_gn`: these store the training and validation sets with gene expression in *TPM* for each transcript, with dimensions *num_samples x n_transcripts*.
#
# Therefore, if you want to introduce different data instead of TCGA, it should have the format mentioned here.

# %%
df_train = data_raw.df_train.drop(['source', 'tumor_type'], axis=1)
df_val = data_raw.df_val.drop(['source','tumor_type'], axis=1)

train_labels = data_raw.train_labels
valid_labels = data_raw.valid_labels

train_gn = data_raw.train_gn
valid_gn = data_raw.valid_gn

# %%
df_train.head()
# Out:
#                      A1CF      AATF     ABCF1      ABT1     ACAA2     ACIN1  \
# TCGA-33-4533-01  0.070387  5.527001  5.321890  4.051357  5.597576  5.755430
# TCGA-90-7964-01  0.014355  5.640976  5.593659  3.828865  3.685968  6.430408
# TCGA-LA-A7SW-01  0.454178  6.271676  6.248680  4.618787  4.041774  6.714093
# TCGA-66-2793-01  0.000000  5.066562  6.457790  4.438928  5.535708  5.759159
# TCGA-21-1076-01  0.021480  4.748974  4.878253  3.513470  5.373491  6.320794
#
#                       ACTB     ACTN1     ACTN4      ADAR  ...    ZNF598  \
# TCGA-LA-A7SW-01         1.940000       102.899059
# TCGA-66-2793-01         4.489886       121.615908
# TCGA-21-1076-01         7.674869        77.481564
#
# [5 rows x 11459 columns]

# %%
print(f'Number of samples for training: {df_train.shape[0]}')
print(f'Number of samples for validation: {df_val.shape[0]}')
# Out:
# Number of samples for training: 993
# Number of samples for validation: 265

# %% [markdown]
# ### 2.2. Scale the RBP input data
# Next, we'll scale the dataset with RBP expression. We'll fit the training set to the standard scaler to compute the scaling parameters and then transform both the training and validation sets.
#
# Afterwards, we'll constrain the values between *-2sigma* and *2sigma*, shift them by *2sigma*, and divide by *4sigma*, so that the expression values are normalized between 0 and 1.
#
# The `data_scale` variable will contain the scaled training and validation sets, along with the scaler object and the sigma value used (a value that tends to 1).

# %%
data_scale = scale_rbp_input_data(df_train, df_val)

# %%
data_scale.scaledTrain_df.head()
# Out:
#                      A1CF      AATF     ABCF1      ABT1     ACAA2     ACIN1  \
# TCGA-33-4533-01  0.396504  0.586747  0.549004  0.638230  0.545793  0.431549
# TCGA-90-7964-01  0.385842  0.631865  0.646026  0.536686  0.214678  0.668920
# TCGA-LA-A7SW-01  0.469530  0.881535  0.879868  0.897202  0.276308  0.768684
# TCGA-66-2793-01  0.383111  0.404478  0.954520  0.815115  0.535077  0.432861
# TCGA-21-1076-01  0.387198  0.278757  0.390626  0.392742  0.506979  0.630372
#
#                      ACTB     ACTN1     ACTN4      ADAR  ...    ZNF598  \
# TCGA-33-4533-01  0.734030  0.664078  0.368639  0.563407  ...  0.392820
# TCGA-90-7964-01  0.507299  0.535379  0.654791  0.583991  ...  0.658109
# TCGA-LA-A7SW-01  0.896434  0.951876  0.817747  0.549164  ...  1.000000
# TCGA-66-2793-01  0.435499  0.397482  0.659927  0.693679  ...  1.000000
# TCGA-21-1076-01  0.640887  0.652174  0.669749  0.703620  ...  0.404113
#
#                    ZNF622    ZNF638    ZNF768     ZNFX1    ZNHIT6    ZRANB2  \
# TCGA-33-4533-01  1.000000  0.386229  0.346040  0.135015  0.911408  0.600449
# TCGA-90-7964-01  0.465896  0.495723  0.542680  0.474366  0.718825  0.428438
# TCGA-LA-A7SW-01  0.599804  0.696238  0.473280  0.506490  0.730500  0.563665
# TCGA-66-2793-01  0.285013  0.777106  0.961948  0.388791  0.945252  0.922233
# TCGA-21-1076-01  0.486151  0.614030  0.171219  0.721319  0.539389  0.602393
#
#                     ZRSR1     ZRSR2       ZYX
# TCGA-33-4533-01  0.591811  0.707293  0.299165
# TCGA-90-7964-01  0.446836  0.296959  0.672170
# TCGA-LA-A7SW-01  0.313044  0.715327  0.631083
# TCGA-66-2793-01  0.313044  0.414701  0.398500
# TCGA-21-1076-01  0.313044  0.655436  0.684763
#
# [5 rows x 1282 columns]

# %%
data_scale.scaledValidation_df.head()
# Out:
#                      A1CF      AATF     ABCF1      ABT1     ACAA2     ACIN1  \
# TCGA-33-4566-01  0.383111  0.446194  0.469529  0.651620  0.169466  0.266505
# TCGA-60-2706-01  0.383111  0.257331  0.838424  0.907845  0.526877  0.567132
# TCGA-90-6837-11  0.383111  0.435958  0.549387  0.468396  0.613895  0.386991
# TCGA-22-1000-01  0.383111  0.393612  0.389386  0.354163  0.431194  0.362745
# TCGA-85-8277-01  0.383111  0.810636  0.945909  0.111489  0.220996  0.364053
#
#                      ACTB     ACTN1     ACTN4      ADAR  ...    ZNF598  \
# TCGA-33-4566-01  0.671017  0.589874  0.175058  0.600740  ...  0.302774
# TCGA-60-2706-01  0.597270  0.558254  0.615572  0.774972  ...  0.939604
# TCGA-90-6837-11  0.726741  0.621069  0.912473  0.631288  ...  0.316958
# TCGA-22-1000-01  0.577524  0.746405  0.633684  0.487077  ...  0.488239
# TCGA-85-8277-01  0.369337  0.489238  0.438195  0.650270  ...  0.637849
#
#                    ZNF622    ZNF638    ZNF768     ZNFX1    ZNHIT6    ZRANB2  \
# TCGA-33-4566-01  0.899345  0.173778  0.000000  0.302199  0.352018  0.309458
# TCGA-60-2706-01  0.435736  0.299208  1.000000  0.527763  0.409715  0.420132
# TCGA-90-6837-11  0.408216  0.281443  0.303724  0.776966  0.516103  0.370867
# TCGA-22-1000-01  0.315244  0.193619  0.204915  0.584074  0.485913  0.352935
# TCGA-85-8277-01  0.468603  0.172900  0.534934  0.324916  0.528255  0.401149
#
#                     ZRSR1     ZRSR2       ZYX
# TCGA-33-4566-01  0.313044  0.000000  0.413533
# TCGA-60-2706-01  0.437110  0.199989  0.532922
# TCGA-90-6837-11  0.512642  0.474307  0.915242
# TCGA-22-1000-01  0.313044  0.295721  0.704985
# TCGA-85-8277-01  0.649664  0.468899  0.337096
#
# [5 rows x 1282 columns]

# %% [markdown]
# ### 2.3. Create training and validation data loaders
# Next, we'll create the training and validation data loaders (`train_loader` and `val_loader`). These loaders will use the normalized RBP expression, transcript expression, and gene expression, needed to fit into the model. In this step, we use the `config` object to determine the batch size. For the validation set, since we are testing, the batch size is set to twice the value assigned in the config.

# %%
train_loader = create_data_loader(scaled_rbps_df=data_scale.scaledTrain_df, labels_df=train_labels, gn_df=train_gn, config=config)
val_loader = create_data_loader(scaled_rbps_df=data_scale.scaledValidation_df, labels_df=valid_labels, gn_df=valid_gn, config=config, set_mode='test')
# Out:
# [Utils][create_data_loader] Creating a training data_loader
# [Utils][create_data_loader] Convert to PyTorch dataset ... -> DONE
# [Utils][create_data_loader] Creating a test data_loader
# [Utils][create_data_loader] Convert to PyTorch dataset ... -> DONE

# %% [markdown]
# ## 3. Create the DeepRBP model object and get the optimizer

# %%
model = DeepRBP(n_inputs=df_train.shape[1], n_outputs=train_labels.shape[1], config=config)
optimizer = build_optimizer(model, config.optimizer, config.learning_rate)
print(model)
# Out:
# You are using a model with 2 hidden layers
# DeepRBP(
#   (linear0): Linear(in_features=1282, out_features=1024, bias=True)
#   (bn0): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (a_function0): ReLU()
#   (linear1): Linear(in_features=1024, out_features=256, bias=True)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (a_function1): ReLU()
#   (final_layer): Linear(in_features=256, out_features=11459, bias=True)
# )

# %% [markdown]
# ## 4. Train the DeepRBP model

# %%
model.fit(
        epochs=config.epochs, 
        train_loader=train_loader, 
        val_loader=val_loader, 
        optimizer=optimizer, 
        path=path_save_files, 
        model_name='model.pt')
# Out:
# Training:   1%|▎                             | 1/100 [00:00<01:16,  1.30epoch/s]
# Epoch 0/100 - Training Loss: {'loss': 9.460707664489746}, Validation Loss: {'val_loss': 7.767425060272217}
# Training:   6%|█▊                            | 6/100 [00:03<00:50,  1.86epoch/s]
# Epoch 5/100 - Training Loss: {'loss': 0.6503445506095886}, Validation Loss: {'val_loss': 0.5434252619743347}
# Training:  11%|███▏                         | 11/100 [00:06<00:46,  1.91epoch/s]
# Epoch 10/100 - Training Loss: {'loss': 0.22756969928741455}, Validation Loss: {'val_loss': 0.23799046874046326}
# Training:  16%|████▋                        | 16/100 [00:08<00:43,  1.91epoch/s]
# Epoch 15/100 - Training Loss: {'loss': 0.18126490712165833}, Validation Loss: {'val_loss': 0.19313272833824158}
# Training:  21%|██████                       | 21/100 [00:11<00:41,  1.92epoch/s]
# Epoch 20/100 - Training Loss: {'loss': 0.16029749810695648}, Validation Loss: {'val_loss': 0.1718820482492447}
# Training:  26%|███████▌                     | 26/100 [00:13<00:39,  1.90epoch/s]
# Epoch 25/100 - Training Loss: {'loss': 0.14951136708259583}, Validation Loss: {'val_loss': 0.15762443840503693}
# Training:  31%|████████▉                    | 31/100 [00:16<00:36,  1.88epoch/s]
# Epoch 30/100 - Training Loss: {'loss': 0.13836590945720673}, Validation Loss: {'val_loss': 0.14914976060390472}
# Training:  36%|██████████▍                  | 36/100 [00:19<00:35,  1.79epoch/s]
# Epoch 35/100 - Training Loss: {'loss': 0.13165168464183807}, Validation Loss: {'val_loss': 0.14232420921325684}
# Training:  41%|███████████▉                 | 41/100 [00:22<00:35,  1.68epoch/s]
# Epoch 40/100 - Training Loss: {'loss': 0.1266697496175766}, Validation Loss: {'val_loss': 0.13670961558818817}
# Training:  46%|█████████████▎               | 46/100 [00:25<00:32,  1.64epoch/s]
# Epoch 45/100 - Training Loss: {'loss': 0.12023498117923737}, Validation Loss: {'val_loss': 0.13191097974777222}
# Training:  51%|██████████████▊              | 51/100 [00:28<00:29,  1.68epoch/s]
# Epoch 50/100 - Training Loss: {'loss': 0.11590653657913208}, Validation Loss: {'val_loss': 0.12817241251468658}
# Training:  56%|████████████████▏            | 56/100 [00:31<00:26,  1.68epoch/s]
# Epoch 55/100 - Training Loss: {'loss': 0.11284075677394867}, Validation Loss: {'val_loss': 0.12525072693824768}
# Training:  61%|█████████████████▋           | 61/100 [00:34<00:23,  1.67epoch/s]
# Epoch 60/100 - Training Loss: {'loss': 0.10986991971731186}, Validation Loss: {'val_loss': 0.12374722957611084}
# Training:  66%|███████████████████▏         | 66/100 [00:37<00:19,  1.73epoch/s]
# Epoch 65/100 - Training Loss: {'loss': 0.10635685920715332}, Validation Loss: {'val_loss': 0.12124522030353546}
# Training:  71%|████████████████████▌        | 71/100 [00:40<00:17,  1.65epoch/s]
#   {'val_loss': 0.14613282680511475},
#   {'val_loss': 0.14424146711826324},
#   {'val_loss': 0.14637862145900726},
#   {'val_loss': 0.14232420921325684},
#   {'val_loss': 0.14033903181552887},
#   {'val_loss': 0.14038832485675812},
#   {'val_loss': 0.13858674466609955},
#   {'val_loss': 0.1389133781194687},
#   {'val_loss': 0.13670961558818817},
#   {'val_loss': 0.13624349236488342},
#   {'val_loss': 0.13798415660858154},
#   {'val_loss': 0.13424059748649597},
#   {'val_loss': 0.13436727225780487},
#   {'val_loss': 0.13191097974777222},
#   {'val_loss': 0.13052406907081604},
#   {'val_loss': 0.1316560059785843},
#   {'val_loss': 0.13050584495067596},
#   {'val_loss': 0.12973710894584656},
#   {'val_loss': 0.12817241251468658},
#   {'val_loss': 0.12769024074077606},
#   {'val_loss': 0.13148197531700134},
#   {'val_loss': 0.12986406683921814},
#   {'val_loss': 0.12636397778987885},
#   {'val_loss': 0.12525072693824768},
#   {'val_loss': 0.12566271424293518},
#   {'val_loss': 0.12394008785486221},
#   {'val_loss': 0.12384006381034851},
#   {'val_loss': 0.1238338053226471},
#   {'val_loss': 0.12374722957611084},
#   {'val_loss': 0.12275168299674988},
#   {'val_loss': 0.12140973657369614},
#   {'val_loss': 0.12105868011713028},
#   {'val_loss': 0.1219528540968895},
#   {'val_loss': 0.12124522030353546},
#   {'val_loss': 0.12034640461206436},
#   {'val_loss': 0.12088147550821304},
#   {'val_loss': 0.11984553188085556},
#   {'val_loss': 0.1190960556268692},
#   {'val_loss': 0.11846330016851425},
#   {'val_loss': 0.11885331571102142},
#   {'val_loss': 0.11828729510307312},
#   {'val_loss': 0.11891523003578186},
#   {'val_loss': 0.11916692554950714},
#   {'val_loss': 0.11704249680042267},
#   {'val_loss': 0.1177048534154892},
#   {'val_loss': 0.11647041887044907},
#   {'val_loss': 0.11506243795156479},
#   {'val_loss': 0.11506416648626328},
#   {'val_loss': 0.11553354561328888},
#   {'val_loss': 0.11504034698009491},
#   {'val_loss': 0.11478538066148758},
#   {'val_loss': 0.11396989971399307},
#   {'val_loss': 0.11267901957035065},
#   {'val_loss': 0.11382366716861725},
#   {'val_loss': 0.11323285102844238},
#   {'val_loss': 0.11593863368034363},
#   {'val_loss': 0.11271746456623077},
#   {'val_loss': 0.11312194913625717},
#   {'val_loss': 0.11165716499090195},
#   {'val_loss': 0.11261756718158722},
#   {'val_loss': 0.11235405504703522},
#   {'val_loss': 0.11241339892148972},
#   {'val_loss': 0.111757293343544},
#   {'val_loss': 0.11143597215414047},
#   {'val_loss': 0.11446534097194672},
#   {'val_loss': 0.11114218831062317},
#   {'val_loss': 0.11243748664855957},
#   {'val_loss': 0.11096081882715225}])

# %% [markdown]
# ## 5. Save the trained DeepRBP model parameters, the scaler and sigma used in results folder

# %%
filename_scaler = os.path.join(path_save_files, 'scaler_sfs.joblib')
filename_sigma = os.path.join(path_save_files, 'sigma_sfs.txt')
joblib.dump(data_scale.scaler_sfs, filename_scaler)
np.savetxt(filename_sigma, [data_scale.sigma_sfs])
